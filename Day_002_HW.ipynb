# %% [markdown]
# ## [作業目標]
# 了解機器學習適合應用的領域與範疇。

# %% [markdown]
# ## [作業重點]
# 透過瞭解機器學習的運作方式，找出非常適用機器學習應用的領域及其原因

# %% [markdown]
# ## 作業
# 請找出一個你認為機器學習可以發光發熱的領域並闡述原因?     Ans:1.電子製造業。2.機器學習在對重複性高、目標明確的事情，以車廠為例，在工廠端能取代大部份的人力。如車廠的車體組裝，機器能精準的組合車體，並且用相同的旋轉力道，相同的旋轉圈數，相同的螺絲數量來確保車子組裝品質。
